# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
city_data = pd.read_csv("raw_data/city_data.csv")
ride_data = pd.read_csv("raw_data/ride_data.csv")

# %%
city_data.head()
# Out:
#              city  driver_count   type
# 0      Kelseyland            63  Urban
# 1      Nguyenbury             8  Urban
# 2    East Douglas            12  Urban
# 3   West Dawnfurt            34  Urban
# 4  Rodriguezburgh            52  Urban

# %%
ride_data.head()
# Out:
#           city                 date   fare        ride_id
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673

# %%
pyber_data = pd.merge(ride_data, city_data, how="left", on=["city"])
pyber_data.head()
# Out:
#           city                 date   fare        ride_id  driver_count   type
# 0     Sarabury  2016-01-16 13:49:27  38.35  5403689035038            46  Urban
# 1    South Roy  2016-01-02 18:42:34  17.49  4036272335942            35  Urban
# 2  Wiseborough  2016-01-21 17:35:29  44.18  3645042422587            55  Urban
# 3  Spencertown  2016-07-31 14:53:22   6.87  2242596575892            68  Urban
# 4   Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673             8  Urban

# %%
clean_total_rides_per_city = ride_data.loc[:, ["city"]]
total_rides_per_city = clean_total_rides_per_city["city"].value_counts()
total_rides_per_city.head()
# Out:
# Port Johnstad    34
# Swansonbury      34
# South Louis      32
# Port James       32
# Williamshire     31
# Name: city, dtype: int64

# %%
clean_total_rides_beta = ride_data.groupby("city").count()
clean_total_rides_beta
# Out:
#                       date  fare  ride_id
# city
# Alvarezhaven            31    31       31
# Alyssaberg              26    26       26
# Anitamouth               9     9        9
# Antoniomouth            22    22       22
# Aprilchester            19    19       19
# Arnoldview              31    31       31
# Campbellport            15    15       15
# Carrollbury             10    10       10
# Carrollfort             29    29       29
# Clarkstad               12    12       12
# Conwaymouth             11    11       11
# Davidtown               21    21       21
# Davistown               25    25       25
# East Cherylfurt         13    13       13
# East Douglas            22    22       22
# East Erin               28    28       28
# East Jenniferchester    19    19       19
# East Leslie             11    11       11
# East Stephen            10    10       10
# East Troybury            7     7        7
# Edwardsbury             27    27       27
# ...

# %%
city_type = pyber_data.groupby("type").size().to_frame(name='counts')
city_type
# Out:
#           counts
# type
# Rural        125
# Suburban     657
# Urban       1625

# %%
avg_fare_per_city = ride_data.groupby("city").mean()["fare"]
avg_fare_per_city.head()
# Out:
# city
# Alvarezhaven    23.928710
# Alyssaberg      20.609615
# Anitamouth      37.315556
# Antoniomouth    23.625000
# Aprilchester    21.981579
# Name: fare, dtype: float64

# %% [markdown]
# ### % of Total Drivers by City Type

# %%
total_drivers_urban = (city_data.loc[city_data["type"] == "Urban"]).sum()["driver_count"]
total_drivers_urban
# Out:
# 2607

# %%
total_drivers_suburban = (city_data.loc[city_data["type"] == "Suburban"]).sum()["driver_count"]
total_drivers_suburban
# Out:
# 638

# %%
total_drivers_rural = (city_data.loc[city_data["type"] == "Rural"]).sum()["driver_count"]
total_drivers_rural
# Out:
# 104

# %%
total_drivers_pie_labels = ["Urban", "Surburban", "Rural"]
total_drivers_pie_sizes = [total_drivers_urban, total_drivers_suburban, total_drivers_rural]
total_drivers_pie_colors = ["lightcoral", "lightskyblue", "gold"]
total_drivers_pie_explode = (0.1, 0, 0)
plt.pie(total_drivers_pie_sizes, 
        explode=total_drivers_pie_explode, 
        labels=total_drivers_pie_labels, 
        colors=total_drivers_pie_colors,
        autopct="%1.1f%%", shadow=True, startangle=210)
plt.axis("equal")
plt.title('% of Total Drivers by City Type')
plt.show()

# %% [markdown]
# ### % of Total Rides by City Type

# %%
group_city_data = pyber_data.groupby("city")
group_city_data.head()
# Out:
#                       city                 date   fare        ride_id  \
# 0                 Sarabury  2016-01-16 13:49:27  38.35  5403689035038
# 1                South Roy  2016-01-02 18:42:34  17.49  4036272335942
# 2              Wiseborough  2016-01-21 17:35:29  44.18  3645042422587
# 3              Spencertown  2016-07-31 14:53:22   6.87  2242596575892
# 4               Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673
# 5              New Jeffrey  2016-02-22 18:36:25  36.01  9757888452346
# 6            Port Johnstad  2016-06-07 02:39:58  17.15  4352278259335
# 7                Jacobfort  2016-09-20 20:58:37  22.98  1500221409082
# 8              Travisville  2016-01-15 17:32:02  27.39   850152768361
# 9               Sandymouth  2016-11-16 07:27:00  21.61  2389035050524
# 10         New Andreamouth  2016-04-11 07:20:48   7.72  9992929847990
# 11           New Christine  2016-09-13 15:06:42  24.89  7918411468537
# ...
